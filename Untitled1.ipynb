# %%
# %load ../../scripts/pendulum/ppo.py
import gym
import keras_gym as km
from tensorflow import keras
from tensorflow.keras import backend as K


###############################################################################
# environment (MDP)
###############################################################################

env = gym.make('Pendulum-v0')
env = km.wrappers.BoxActionsToReals(env)
env = km.wrappers.TrainMonitor(
    env=env, tensorboard_dir='/tmp/tensorboard/pendulum/ppo_static')
km.enable_logging()


###############################################################################
# function approximator
###############################################################################

class MLP(km.FunctionApproximator):
    def body(self, X):
        X = keras.layers.Lambda(
            lambda x: K.concatenate([x, K.square(x)], axis=1))(X)
        X = keras.layers.Dense(units=6, activation='tanh')(X)
        X = keras.layers.Dense(units=6, activation='tanh')(X)
        return X


mlp = MLP(env, lr=1e-3)
pi = km.GaussianPolicy(mlp, update_strategy='ppo')
v = km.V(mlp, gamma=0.9, bootstrap_n=5)
ac = km.ActorCritic(pi, v)


buffer = km.caching.ExperienceReplayBuffer.from_value_function(
    value_function=v, capacity=512, batch_size=32)


###############################################################################
# run
###############################################################################

while env.T < 1000000:
    s = env.reset()
    for t in range(env.spec.max_episode_steps):
        a = pi(s, use_target_model=True)
        s_next, r, done, info = env.step(a)

        buffer.add(s, a, r, done, env.ep)
        if len(buffer) >= buffer.capacity:
            # use 4 epochs per round
            num_batches = int(4 * buffer.capacity / buffer.batch_size)
            for _ in range(num_batches):
                ac.batch_update(*buffer.sample())
            buffer.clear()
            pi.sync_target_model(tau=0.1)

        if done:
            break

        s = s_next
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 # %load ../../scripts/pendulum/ppo.py
#       2 import gym
# ----> 3 import keras_gym as km
#       4 from tensorflow import keras
#       5 from tensorflow.keras import backend as K
#
# ModuleNotFoundError: No module named 'keras_gym'

# %%
# %pip install keras_gym
# Out:
# Collecting keras_gym
#   Downloading keras_gym-0.2.17-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 KB 869.5 kB/s eta 0:00:000:01:00:01
# Requirement already satisfied: absl-py>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (0.15.0)
# Requirement already satisfied: pandas>=0.23.4 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (1.4.1)
# Requirement already satisfied: Pillow>=6.0.0 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (9.0.1)
# Requirement already satisfied: scipy>=1.2.1 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (1.8.0)
# Requirement already satisfied: gym>=0.12.1 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (0.23.1)
# Collecting numpy<1.17,>=1.16
#   Downloading numpy-1.16.6.zip (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 1.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=1.14 in /opt/conda/lib/python3.9/site-packages (from keras_gym) (2.6.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from absl-py>=0.8.1->keras_gym) (1.15.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /opt/conda/lib/python3.9/site-packages (from gym>=0.12.1->keras_gym) (4.11.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from gym>=0.12.1->keras_gym) (2.0.0)
# Collecting gym>=0.12.1
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 KB 1.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 KB 1.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#   Downloading gym-0.20.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 987.4 kB/s eta 0:00:00:0100:01
#   Preparing metadata (setup.py) ... done
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 723.6 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 689.9 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting pyglet<=1.5.15,>=1.4.0
#   Downloading pyglet-1.5.15-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 917.2 kB/s eta 0:00:0000:0100:01
# Collecting Pillow>=6.0.0
#   Downloading Pillow-8.2.0-cp39-cp39-manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting cloudpickle<1.7.0,>=1.2.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.23.4->keras_gym) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=0.23.4->keras_gym) (2021.3)
# Collecting pandas>=0.23.4
#   Downloading pandas-1.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 911.2 kB/s eta 0:00:0000:010:01
#   Downloading pandas-1.3.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 812.7 kB/s eta 0:00:0000:0100:01
#   Downloading pandas-1.3.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 1.3 MB/s eta 0:00:0000:0100:01m
#   Downloading pandas-1.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 1.5 MB/s eta 0:00:0000:0100:01
#   Downloading pandas-1.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 845.6 kB/s eta 0:00:0000:0100:01
#   Downloading pandas-1.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 777.7 kB/s eta 0:00:0000:0100:01
#   Downloading pandas-1.3.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 1.0 MB/s eta 0:00:0000:0100:01m
#   Downloading pandas-1.2.5-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 797.9 kB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.2.1
#   Downloading scipy-1.7.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.8/39.8 MB 978.6 kB/s eta 0:00:000:0100:01m
# Requirement already satisfied: gast==0.4.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (0.4.0)
# Collecting tensorflow>=1.14
#   Downloading tensorflow-2.8.0-cp39-cp39-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB ? eta 0:00:000:00:0100:18977.6 kB/s eta 0:00:01977.6 kB/s eta 0:00:01977.6 kB/s eta 0:00:01╸ 497.6/497.6 MB 977.6 kB/s eta 0:00:01977.6 kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (59.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.12)
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-manylinux1_x86_64.whl (14.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 885.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.41.1)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 1.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (3.18.1)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow>=1.14->keras_gym) (1.1.2)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.5 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow>=1.14
#   Downloading tensorflow-2.7.1-cp39-cp39-manylinux2010_x86_64.whl (495.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 283.4/495.2 MB 1.0 MB/s eta 0:03:32
